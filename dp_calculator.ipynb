# %%
# Import
import pandas as pd
from bs4 import BeautifulSoup as bs
from splinter import Browser
from time import sleep

# %%
# Initialize Browser
executable_path = {'executable_path': 'c:/bin/chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=True)

# Variables
player_table = []

hitter_tables_2019_2020 = [
    {
        "salary": .5,
        "r_low": 53,
        "r_high": 63,
        "hr_low": 16,
        "hr_high": 19,
        "rbi_low": 51,
        "rbi_high": 60,
        "sb_low": 5,
        "sb_high": 7,
        "avg_low": .253,
        "avg_high": .264,
        "ops_low": .762,
        "ops_high": .796
    },
    {    
        "salary": 1,
        "r_low": 63,
        "r_high": 76,
        "hr_low": 20,
        "hr_high": 25,
        "rbi_low": 61,
        "rbi_high": 74,
        "sb_low": 8,
        "sb_high": 11,
        "avg_low": .265,
        "avg_high": .282,
        "ops_low": .797,
        "ops_high": .854    
    },
    {
        "salary": 1.5,
        "r_low": 77,
        "r_high": 84,
        "hr_low": 26,
        "hr_high": 28,
        "rbi_low": 75,
        "rbi_high": 82,
        "sb_low": 12,
        "sb_high": 13,
        "avg_low": .283,
        "avg_high": .292,
        "ops_low": .855,
        "ops_high": .885     
    },
    {
        "salary": 2,
        "r_low": 85,
        "r_high": 94,
        "hr_low": 29,
         "hr_high": 31,
        "rbi_low": 83,
        "rbi_high": 91,
        "sb_low": 14,
        "sb_high": 16,
        "avg_low": .293,
        "avg_high": .304,
        "ops_low": .886,
        "ops_high": .922      
    },
    {
        "salary": 2.5,
        "r_low": 95,
        "r_high": 117,
        "hr_low": 32,
        "hr_high": 41,
        "rbi_low": 92,
        "rbi_high": 115,
        "sb_low": 17,
        "sb_high": 22,
        "avg_low": .305,
        "avg_high": .333,
        "ops_low": .923,
        "ops_high": 1.015  
    },
    {
        "salary": 3,
        "r_low": 118,
        "r_high": 999,
        "hr_low": 42,
        "hr_high": 999,
        "rbi_low": 116,
        "rbi_high": 999,
        "sb_low": 23,
        "sb_high": 999,
        "avg_low": .334,
        "avg_high": .999,
        "ops_low": 1.016,
        "ops_high": 1.200  
    }
]

pitcher_tables_2019_2020 = [
    {
        "salary": 0.75,
        "sp_k_low": 130,
        "sp_k_high": 148,
        "rp_k_low": 70,
        "rp_k_high": 76,
        "w_low": 8,
        "w_high": 10,
        "sv_low": 6,
        "sv_high": 9,
        "hld_low": 10,
        "hld_high": 13,
        "sp_era_low": 4.16,
        "sp_era_high": 4.53,
        "rp_era_low": 3.70,
        "rp_era_high": 4.06,
        "sp_whip_low": 1.26,
        "sp_whip_high": 1.31,
        "rp_whip_low": 1.21,
        "rp_whip_high": 1.28
    },
    {
        "salary": 1.5,
        "sp_k_low": 149,
        "sp_k_high": 179,
        "rp_k_low": 77,
        "rp_k_high": 86,
        "w_low": 11,
        "w_high": 12,
        "sv_low": 10,
        "sv_high": 14,
        "hld_low": 14,
        "hld_high": 17,
        "sp_era_low": 3.52,
        "sp_era_high": 4.15,
        "rp_era_low": 3.07,
        "rp_era_high": 3.69,
        "sp_whip_low": 1.15,
        "sp_whip_high": 1.25,
        "rp_whip_low": 1.09,
        "rp_whip_high": 1.20        
    },
    {
        "salary": 2.25,
        "sp_k_low": 180,
        "sp_k_high": 195,
        "rp_k_low": 87,
        "rp_k_high": 92,
        "w_low": 13,
        "w_high": 13,
        "sv_low": 15,
        "sv_high": 17,
        "hld_low": 18,
        "hld_high": 19,
        "sp_era_low": 3.17,
        "sp_era_high": 3.51,
        "rp_era_low": 2.73,
        "rp_era_high": 3.06,
        "sp_whip_low": 1.10,
        "sp_whip_high": 1.14,
        "rp_whip_low": 1.02,
        "rp_whip_high": 1.08
    },
    {
        "salary": 3,
        "sp_k_low": 196,
        "sp_k_high": 216,
        "rp_k_low": 93,
        "rp_k_high": 99,
        "w_low": 14,
        "w_high": 15,
        "sv_low": 18,
        "sv_high": 20,
        "hld_low": 20,
        "hld_high": 22,
        "sp_era_low": 2.75,
        "sp_era_high": 3.16,
        "rp_era_low": 2.31,
        "rp_era_high": 2.72,
        "sp_whip_low": 1.03,
        "sp_whip_high": 1.09,
        "rp_whip_low": .94,
        "rp_whip_high": 1.01
    },
    {
        "salary": 3.75,
        "sp_k_low": 217,
        "sp_k_high": 265,
        "rp_k_low": 100,
        "rp_k_high": 115,
        "w_low": 16,
        "w_high": 19,
        "sv_low": 21,
        "sv_high": 29,
        "hld_low": 23,
        "hld_high": 29,
        "sp_era_low": 1.73,
        "sp_era_high": 2.74,
        "rp_era_low": 1.31,
        "rp_era_high": 2.30,
        "sp_whip_low": .87,
        "sp_whip_high": 1.02,
        "rp_whip_low": .75,
        "rp_whip_high": .93
    },
    {
        "salary": 4.5,
        "sp_k_low": 266,
        "sp_k_high": 999,
        "rp_k_low": 116,
        "rp_k_high": 999,
        "w_low": 20,
        "w_high": 99,
        "sv_low": 30,
        "sv_high": 99,
        "hld_low": 30,
        "hld_high": 99,
        "sp_era_low": 0,
        "sp_era_high": 1.72,
        "rp_era_low": 0,
        "rp_era_high": 1.30,
        "sp_whip_low": 0,
        "sp_whip_high": .86,
        "rp_whip_low": 0,
        "rp_whip_high": .74
    }
]

hitter_tables = [
    {
        "salary": .5,
        "r_low": 51,
        "r_high": 59,
        "hr_low": 14,
        "hr_high": 17,
        "rbi_low": 49,
        "rbi_high": 57,
        "sb_low": 5,
        "sb_high": 7,
        "avg_low": .245,
        "avg_high": .256,
        "ops_low": .733,
        "ops_high": .764
    },
    {    
        "salary": 1,
        "r_low": 60,
        "r_high": 73,
        "hr_low": 18,
        "hr_high": 23,
        "rbi_low": 58,
        "rbi_high": 71,
        "sb_low": 8,
        "sb_high": 11,
        "avg_low": .257,
        "avg_high": .274,
        "ops_low": .765,
        "ops_high": .818    
    },
    {
        "salary": 1.5,
        "r_low": 74,
        "r_high": 80,
        "hr_low": 24,
        "hr_high": 26,
        "rbi_low": 72,
        "rbi_high": 78,
        "sb_low": 12,
        "sb_high": 12,
        "avg_low": .275,
        "avg_high": .284,
        "ops_low": .819,
        "ops_high": .847     
    },
    {
        "salary": 2,
        "r_low": 81,
        "r_high": 89,
        "hr_low": 27,
         "hr_high": 29,
        "rbi_low": 79,
        "rbi_high": 87,
        "sb_low": 13,
        "sb_high": 15,
        "avg_low": .285,
        "avg_high": .296,
        "ops_low": .848,
        "ops_high": .883      
    },
    {
        "salary": 2.5,
        "r_low": 90,
        "r_high": 112,
        "hr_low": 30,
        "hr_high": 38,
        "rbi_low": 88,
        "rbi_high": 109,
        "sb_low": 16,
        "sb_high": 20,
        "avg_low": .297,
        "avg_high": .325,
        "ops_low": .885,
        "ops_high": .970  
    },
    {
        "salary": 3,
        "r_low": 113,
        "r_high": 999,
        "hr_low": 39,
        "hr_high": 999,
        "rbi_low": 110,
        "rbi_high": 999,
        "sb_low": 21,
        "sb_high": 999,
        "avg_low": .326,
        "avg_high": .999,
        "ops_low": .971,
        "ops_high": 1.500  
    }
]

pitcher_tables = [
    {
        "salary": 0.75,
        "sp_k_low": 121,
        "sp_k_high": 136,
        "rp_k_low": 69,
        "rp_k_high": 74,
        "w_low": 7,
        "w_high": 8,
        "sv_low": 6,
        "sv_high": 9,
        "hld_low": 10,
        "hld_high": 12,
        "sp_era_low": 3.99,
        "sp_era_high": 4.37,
        "rp_era_low": 3.22,
        "rp_era_high": 3.57,
        "sp_whip_low": 1.22,
        "sp_whip_high": 1.28,
        "rp_whip_low": 1.16,
        "rp_whip_high": 1.23
    },
    {
        "salary": 1.5,
        "sp_k_low": 137,
        "sp_k_high": 164,
        "rp_k_low": 75,
        "rp_k_high": 84,
        "w_low": 9,
        "w_high": 11,
        "sv_low": 10,
        "sv_high": 14,
        "hld_low": 13,
        "hld_high": 16,
        "sp_era_low": 3.32,
        "sp_era_high": 3.98,
        "rp_era_low": 2.60,
        "rp_era_high": 3.21,
        "sp_whip_low": 1.12,
        "sp_whip_high": 1.21,
        "rp_whip_low": 1.05,
        "rp_whip_high": 1.15        
    },
    {
        "salary": 2.25,
        "sp_k_low": 165,
        "sp_k_high": 178,
        "rp_k_low": 85,
        "rp_k_high": 89,
        "w_low": 12,
        "w_high": 12,
        "sv_low": 15,
        "sv_high": 17,
        "hld_low": 17,
        "hld_high": 18,
        "sp_era_low": 2.97,
        "sp_era_high": 3.31,
        "rp_era_low": 2.28,
        "rp_era_high": 2.59,
        "sp_whip_low": 1.06,
        "sp_whip_high": 1.11,
        "rp_whip_low": .99,
        "rp_whip_high": 1.04
    },
    {
        "salary": 3,
        "sp_k_low": 179,
        "sp_k_high": 196,
        "rp_k_low": 90,
        "rp_k_high": 95,
        "w_low": 13,
        "w_high": 13,
        "sv_low": 18,
        "sv_high": 21,
        "hld_low": 19,
        "hld_high": 21,
        "sp_era_low": 2.54,
        "sp_era_high": 2.98,
        "rp_era_low": 1.88,
        "rp_era_high": 2.27,
        "sp_whip_low": .99,
        "sp_whip_high": 1.05,
        "rp_whip_low": .92,
        "rp_whip_high": .98
    },
    {
        "salary": 3.75,
        "sp_k_low": 197,
        "sp_k_high": 239,
        "rp_k_low": 96,
        "rp_k_high": 110,
        "w_low": 14,
        "w_high": 16,
        "sv_low": 22,
        "sv_high": 29,
        "hld_low": 22,
        "hld_high": 27,
        "sp_era_low": 1.48,
        "sp_era_high": 2.53,
        "rp_era_low": .90,
        "rp_era_high": 1.87,
        "sp_whip_low": .82,
        "sp_whip_high": .98,
        "rp_whip_low": .75,
        "rp_whip_high": .91
    },
    {
        "salary": 4.5,
        "sp_k_low": 240,
        "sp_k_high": 999,
        "rp_k_low": 111,
        "rp_k_high": 999,
        "w_low": 17,
        "w_high": 99,
        "sv_low": 30,
        "sv_high": 99,
        "hld_low": 28,
        "hld_high": 99,
        "sp_era_low": 0,
        "sp_era_high": 1.47,
        "rp_era_low": 0,
        "rp_era_high": .89,
        "sp_whip_low": 0,
        "sp_whip_high": .81,
        "rp_whip_low": 0,
        "rp_whip_high": .74
    }
]

# %%
# Read csv
dp_list = pd.read_csv('dp_salary_input.csv')

dp_years = dp_list['dpyear']
urls = dp_list['url']

# %%
dp_list
# Out:
#    dpyear                                                url
# 0       3  https://www.fangraphs.com/players/tyler-stephe...
# 1       3  https://www.fangraphs.com/players/taylor-walls...
# 2       3  https://www.fangraphs.com/players/santiago-esp...
# 3       3  https://www.fangraphs.com/players/manny-banuel...
# 4       3  https://www.fangraphs.com/players/lamonte-wade...
# 5       3  https://www.fangraphs.com/players/johan-oviedo...
# 6       4  https://www.fangraphs.com/players/richie-marti...
# 7       6  https://www.fangraphs.com/players/rafael-orteg...
# 8       6  https://www.fangraphs.com/players/jaime-barria...

# %%
# Loop for each player in dp_salary_input.csv
csv_loop_count = 0
for url in urls:

    # Player Link and DP Year
    fg_link = url
    dp_year = dp_years[csv_loop_count]
    # print(csv_loop_count)
    # print(fg_link)
    
    # Get Soup
    browser.visit(fg_link)
    html = browser.html
    soup = bs(html, 'html.parser')
    
    # Get Player Name
    player_name = soup.select('#content > div.player-info-new > div > div.player-info-box-header > div.player-info-box-name > h1')[0].text

    # Determine If Pitcher or Hitter

    #################################
    ####### P I T C H E R S #########
    #################################
    if 'position=P' in fg_link:

        # Player Stats
        player_stats = soup.select('#standard > div:nth-child(3) > div > div > div > div.table-fixed')

        # Variables
        total_w = 0
        total_g = 0
        total_sv = 0
        total_hld = 0
        total_ip = 0
        total_h = 0
        total_er = 0
        total_bb = 0
        total_so = 0
        dp_modifier = 0
        final_position = ""

        for div in player_stats:

            # For each row of data that has MLB stats
            for mlb_stats in div.findAll('tr', {'class': 'row-mlb-season'}):

                # Create/clear yearly stats
                stats_year = mlb_stats.findAll('td', {'data-stat': 'Season'})[0].text

                # Get totals for last 2 years
                if stats_year == '2022': # or stats_year == '2020':

                    # Wins
                    ws = mlb_stats.findAll('td', {'data-stat': 'W'})[0].text
                    total_w += int(ws)

                    # Games (Appearances)
                    gs = mlb_stats.findAll('td', {'data-stat': 'G'})[0].text
                    total_g += int(gs)           

                    # Saves
                    svs = mlb_stats.findAll('td', {'data-stat': 'SV'})[0].text
                    total_sv += int(svs)

                    # Holds
                    hlds = mlb_stats.findAll('td', {'data-stat': 'HLD'})[0].text
                    total_hld += int(hlds)           

                    # Innings Pitched
                    ips = mlb_stats.findAll('td', {'data-stat': 'IP'})[0].text
                    total_ip += float(ips)

                    # Hits Allowed
                    hits = mlb_stats.findAll('td', {'data-stat': 'H'})[0].text
                    total_h += int(hits)

                    # Earned Runs Allowed
                    ers = mlb_stats.findAll('td', {'data-stat': 'ER'})[0].text
                    total_er += int(ers)

                    # Walks Allowed
                    bbs = mlb_stats.findAll('td', {'data-stat': 'BB'})[0].text
                    total_bb += int(bbs)            

                    # Strikeouts
                    ks = mlb_stats.findAll('td', {'data-stat': 'SO'})[0].text
                    total_so += int(ks)
                    
                    # Pitcher DP Modifier
                    full_ip = str(total_ip).split('.')[0]
                    fractional_ip = str(total_ip).split('.')[1]
                    if fractional_ip == '0':
                        dp_ip = float(full_ip)
                    if fractional_ip == '1':
                        dp_ip = float(full_ip) + .34
                    if fractional_ip == '2':
                        dp_ip = float(full_ip) + .67                    
                    dp_modifier = dp_ip / 200

        # Rate Stats
        # ERA
        try:
            era = round(9 *  total_er / total_ip, 2)
        except:
            era = 100

        #WHIP
        try:
            whip = round((total_bb + total_h) / total_ip, 2)
        except:
            whip = 100

        # IP per appearance
        try:
            ip_per_app = total_ip / total_g
        except:
            ip_per_app = 0

        # Determine position for DP charts
        if ip_per_app < 3:
            final_position = 'RP'
        else:
            final_position = 'SP'    

        player_stats_dict = {
            'pos': final_position,
            'w': total_w,
            'g': total_g,
            'sv': total_sv,
            'hld': total_hld,
            'ip': total_ip,
            'so': total_so,
            'era': era,
            'whip': whip
        }

        # Salary Processing
        sal_k = 0
        sal_w = 0
        sal_era = 0
        sal_whip = 0
        sal_sv = 0
        sal_hld = 0

        for row in pitcher_tables:

            # W Salary
            if (total_w >= row['w_low']) & (total_w <= row['w_high']):
                sal_w += row['salary']

            # SV Salary
            if (total_sv >= row['sv_low']) & (total_sv <= row['sv_high']):
                sal_sv += row['salary']

            # HLD Salary
            if (total_hld >= row['hld_low']) & (total_hld <= row['hld_high']):
                sal_hld += row['salary']

            # RP
            if final_position == 'RP':

                # K Salary
                if (total_so >= row['rp_k_low']) & (total_so <= row['rp_k_high']):
                    sal_k += (row['salary'] * dp_modifier)

                # ERA Salary
                if (era >= row['rp_era_low']) & (era <= row['rp_era_high']):
                    sal_era += (row['salary'] * dp_modifier)

                # WHIP Salary
                if (whip >= row['rp_whip_low']) & (whip <= row['rp_whip_high']):
                    sal_whip += (row['salary'] * dp_modifier)

            # SP
            if final_position == 'SP':

                # K Salary
                if (total_so >= row['sp_k_low']) & (total_so <= row['sp_k_high']):
                    sal_k += (row['salary'] * dp_modifier)

                # ERA Salary
                if (era >= row['sp_era_low']) & (era <= row['sp_era_high']):
                    sal_era += (row['salary'] * dp_modifier)

                # WHIP Salary
                if (whip >= row['sp_whip_low']) & (whip <= row['sp_whip_high']):
                    sal_whip += (row['salary'] * dp_modifier)

        total_value = sal_k + sal_era + sal_whip + sal_sv + sal_hld + sal_w

        # Final Salary - Apply DP rates
        final_salary = 0
        if dp_year == 1:
            final_salary = 0.3
        elif dp_year == 2:
            final_salary = 0.5
        elif dp_year == 3:
            final_salary = total_value * 0.3
        elif dp_year == 4:
            final_salary = total_value * 0.4
        elif dp_year == 5:
            final_salary = total_value * 0.6
        elif dp_year == 6:
            final_salary = total_value * 0.8
        else:
            final_salary = total_value
            
        if (total_value == 0 and dp_year != 0) or final_salary < 0.5:
            final_salary = 0.5    

        ffs_valuation = total_value * 3
        
        player_table.append({
            "Player Name": player_name,
            "Total Value": total_value,
            "Total Salary": round(final_salary,2),
            "FFS Valuation": ffs_valuation,
            "FG Link": fg_link,
            "Position": final_position,
            "W": total_w,
            "W Salary": sal_w,
            "SO": total_so,
            "SO Salary": sal_k,
            "ERA": era,
            "ERA Salary": sal_era,
            "WHIP": whip,
            "WHIP Salary": sal_whip,
            "SV": total_sv,
            "SV Salary": sal_sv,
            "HLD": total_hld,
            "HLD Salary": sal_hld,
            "Pitching Modifier": dp_modifier
        })
        
        print(f'{player_name}')
        print(f'POS: {final_position}')
        print(f'W({total_w}): ${sal_w}')
        print(f'SO({total_so}): ${sal_k}')
        print(f'ERA({era}): ${sal_era}')
        print(f'WHIP({whip}): ${sal_whip}')
        print(f'SV({total_sv}): ${sal_sv}')
        print(f'HLD({total_hld}): ${sal_hld}')
        print(f'Total Value: ${total_value}')
        print(f'Total Salary: ${round(final_salary, 2)}')
        print(f'Projected FFS Valuation: ${ffs_valuation}')
        print(f'Pitching Modifier: {dp_modifier}')
        print('')


    #################################
    ######### H I T T E R S #########
    #################################
    if 'position=P' not in fg_link:

        # Player Positions
        player_header = soup.findAll('div', {'class': 'player-page-table__header'})

        # Variables
        positions = []
        gp_by_pos = []

        # Fangraphs Player Header
        for div in player_header:

            # Set count to skip first th row ('<Year> Games Played')
            count = 0

            # For each table header
            for th in div.findAll('th'):

                # If entry is not the first th
                if count > 0:
                    pos = th.text
                    pos = pos.replace(':', '').strip()
                    positions.append(pos)

                # Increment count
                count += 1

            # For each table data
            for td in div.findAll('td'):

                gp = td.text
                gp_by_pos.append(gp)

        player_pos = {
            "position": positions,
            "games_played": gp_by_pos
        }

        # Player Stats
        player_stats = soup.select('#standard > div:nth-child(3) > div > div > div > div.table-fixed')

        # Variables
        total_abs = 0
        total_hits = 0
        total_1b = 0
        total_2b = 0
        total_3b = 0
        total_runs = 0
        total_hrs = 0
        total_rbi = 0
        total_bb = 0
        total_hbp = 0
        total_sf = 0
        total_sb = 0

        # Fangraphs Player Stats (Standard) Table
        for div in player_stats:

            # For each row of data that has MLB stats
            for mlb_stats in div.findAll('tr', {'class': 'row-mlb-season'}):

                # Create/clear yearly stats
                stats_year = mlb_stats.findAll('td', {'data-stat': 'Season'})[0].text

                # Get totals for last 2 years
                if stats_year == '2022': # or stats_year == '2020':

                    # At Bats
                    atbats = mlb_stats.findAll('td', {'data-stat': 'AB'})[0].text
                    total_abs += int(atbats)           

                    # Hits
                    hits = mlb_stats.findAll('td', {'data-stat': 'H'})[0].text
                    total_hits += int(hits)            

                    # Singles
                    singles = mlb_stats.findAll('td', {'data-stat': '1B'})[0].text
                    total_1b += int(singles)             

                    # Doubles
                    doubles = mlb_stats.findAll('td', {'data-stat': '2B'})[0].text
                    total_2b += int(doubles)  

                    # Triples
                    triples = mlb_stats.findAll('td', {'data-stat': '3B'})[0].text
                    total_3b += int(triples)  

                    # Runs
                    runs = mlb_stats.findAll('td', {'data-stat': 'R'})[0].text
                    total_runs += int(runs)

                    # Homeruns
                    homeruns = mlb_stats.findAll('td', {'data-stat': 'HR'})[0].text
                    total_hrs += int(homeruns)

                    # RBI
                    rbis = mlb_stats.findAll('td', {'data-stat': 'RBI'})[0].text
                    total_rbi += int(rbis)            

                    # Walks
                    bbs = mlb_stats.findAll('td', {'data-stat': 'BB'})[0].text
                    total_bb += int(bbs)

                    # Hit by pitch
                    hbps = mlb_stats.findAll('td', {'data-stat': 'HBP'})[0].text
                    total_hbp += int(hbps)               

                    # Sacrifices
                    sfs = mlb_stats.findAll('td', {'data-stat': 'SF'})[0].text
                    total_sf += int(sfs)               

                    # SB
                    sbs = mlb_stats.findAll('td', {'data-stat': 'SB'})[0].text
                    total_sb += int(sbs)

        # Batting Average
        try:
            avg = round(total_hits/total_abs, 3)
        except:
            avg = 0

        # OPS
        try:
            ops = round(((total_hits + total_bb + total_hbp) / (total_abs + total_bb + total_sf + total_hbp)) + (((total_1b) + (total_2b * 2) + (total_3b * 3) + (4 * total_hrs)) / total_abs), 3)
        except:
            ops = 0
            
        player_stats_dict = {
            'ab': total_abs,
            'h': total_hits,
            'r': total_runs,
            'hr': total_hrs,
            'rbi': total_rbi,
            'sb': total_sb,
            'avg': avg,
            'ops': ops
        }

        # Salary Processing
        sal_r = 0
        sal_hr = 0
        sal_rbi = 0
        sal_sb = 0
        sal_avg = 0
        sal_ops = 0

        for row in hitter_tables:

            # R Salary
            if (total_runs >= row['r_low']) & (total_runs <= row['r_high']):
                sal_r += row['salary']

            # HR Salary
            if (total_hrs >= row['hr_low']) & (total_hrs <= row['hr_high']):
                sal_hr += row['salary']

            # RBI Salary
            if (total_rbi >= row['rbi_low']) & (total_rbi <= row['rbi_high']):
                sal_rbi += row['salary']

            # SB Salary
            if (total_sb >= row['sb_low']) & (total_sb <= row['sb_high']):
                sal_sb += row['salary']

            # AVG Salary
            if total_abs > 149:
                if (avg >= row['avg_low']) & (avg <= row['avg_high']):
                    sal_avg += row['salary']

            # OPS Salary
            if total_abs > 149:
                if (ops >= row['ops_low']) & (ops <= row['ops_high']):
                    sal_ops += row['salary']

        total_value = sal_r + sal_hr + sal_rbi + sal_sb + sal_avg + sal_ops

        # Final Salary - Apply DP rates
        final_salary = 0
        if dp_year == 1:
            final_salary = 0.3
        elif dp_year == 2:
            final_salary = 0.5
        elif dp_year == 3:
            final_salary = total_value * 0.3
        elif dp_year == 4:
            final_salary = total_value * 0.4
        elif dp_year == 5:
            final_salary = total_value * 0.6
        elif dp_year == 6:
            final_salary = total_value * 0.8
        else:
            final_salary = 9999
        
        
        if (total_value == 0 and dp_year != 0) or final_salary < 0.5:
            final_salary = 0.5
            
        ffs_valuation = total_value * 3
        
        player_table.append({
            "Player Name": player_name,
            "Total Value": total_value,
            "Total Salary": round(final_salary,2),
            "FFS Valuation": ffs_valuation,
            "FG Link": fg_link,
            "R": total_runs,
            "R Salary": sal_r,
            "HR": total_hrs,
            "HR Salary": sal_hr,
            "RBI": total_rbi,
            "RBI Salary": sal_rbi,
            "SB": total_sb,
            "SB Salary": sal_sb,
            "AVG": avg,
            "AVG Salary": sal_avg,
            "OPS": ops,
            "OPS Salary": sal_ops
        })

        print(f'{player_name}')
        print(f'R({total_runs}): ${sal_r}')
        print(f'HR({total_hrs}): ${sal_hr}')
        print(f'RBI({total_rbi}): ${sal_rbi}')
        print(f'SB({total_sb}): ${sal_sb}')
        print(f'AVG({avg}): ${sal_avg}')
        print(f'OPS({ops}): ${sal_ops}')
        print(f'Total Value: ${total_value}')
        print(f'Total Salary: ${round(final_salary,2)}')
        print(f'Projected FFS Valuation: ${ffs_valuation}')
        print('')
    
    csv_loop_count += 1
    sleep(5)
# Out:
# Tyler Stephenson
# R(24): $0
# HR(6): $0
# RBI(35): $0
# SB(1): $0
# AVG(0.319): $2.5
# OPS(0.854): $2
# Total Value: $4.5
# Total Salary: $1.35
# Projected FFS Valuation: $13.5
#
# Taylor Walls
# R(43): $0
# HR(6): $0
# RBI(30): $0
# SB(8): $1
# AVG(0.173): $0
# OPS(0.537): $0
# Total Value: $1
# Total Salary: $0.5
# Projected FFS Valuation: $3
#
# Santiago Espinal
# R(48): $0
# HR(7): $0
# RBI(49): $0.5
# SB(6): $0.5
# AVG(0.263): $1
# OPS(0.689): $0
# Total Value: $2.0
# Total Salary: $0.6
# Projected FFS Valuation: $6.0
#
# Manny Bañuelos
# POS: RP
# W(1): $0
# SO(32): $0
# ERA(3.44): $0.1275
# WHIP(1.15): $0.255
# SV(1): $0
# HLD(5): $0
# Total Value: $0.3825
# Total Salary: $0.5
# Projected FFS Valuation: $1.1475
# Pitching Modifier: 0.17
#
# LaMonte Wade Jr.
# R(22): $0
# HR(8): $0
# RBI(24): $0
# SB(0): $0
# AVG(0.191): $0
# OPS(0.657): $0
# Total Value: $0
# Total Salary: $0.5
# Projected FFS Valuation: $0
#
# Johan Oviedo
# POS: RP
# W(0): $0
# SO(0): $0
# ERA(100): $0
# WHIP(100): $0
# SV(0): $0
# HLD(0): $0
# Total Value: $0
# Total Salary: $0.5
# Projected FFS Valuation: $0
# Pitching Modifier: 0
#
# Richie Martin
# R(4): $0
# HR(0): $0
# RBI(3): $0
# SB(3): $0
# AVG(0.167): $0
# OPS(0.542): $0
# Total Value: $0
# Total Salary: $0.5
# Projected FFS Valuation: $0
#
# Rafael Ortega
# R(35): $0
# HR(7): $0
# RBI(35): $0
# SB(12): $1.5
# AVG(0.241): $0
# OPS(0.688): $0
# Total Value: $1.5
# Total Salary: $1.2
# Projected FFS Valuation: $4.5
#
# Jaime Barría
# POS: RP
# W(2): $0
# SO(48): $0
# ERA(2.62): $0.545025
# WHIP(1.0): $0.8175375
# SV(0): $0
# HLD(2): $0
# Total Value: $1.3625625000000001
# Total Salary: $1.09
# Projected FFS Valuation: $4.0876875
# Pitching Modifier: 0.36335

# %%
# Player Positions
# player_pos_df = pd.DataFrame(player_pos)
# player_pos_df

# %%
pd.set_option("display.max_columns", None)
player_df = pd.DataFrame(player_table)
player_df
player_df.to_csv (r'C:\Users\root\Desktop\FFSMLB\players\dps.csv', index = False, header=True)
